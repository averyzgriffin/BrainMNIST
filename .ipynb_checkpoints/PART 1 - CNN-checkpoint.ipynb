# %%
import numpy as np
import h5py
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import TensorBoard

# %% [markdown]
# ## Functions

# %%
def load_data(filename, dataname):
    with h5py.File(filename, 'r') as hf:
        x = hf[dataname][:]
    with h5py.File('EP_preprocessed_y.h5', 'r') as hf:
        y = hf['EP_preprocessed_y_dataset'][:]
    return x,y

# %%
def reshape_x(pre_x, channels, timepoints):
    new_x = np.reshape(pre_x, (pre_x.shape[0], channels, timepoints))
    return new_x

# %%
def train_test_split(file, data):
    x_,y_ = load_data(file, data)
    
    x_train, x_test = x_[:int(len(x_)*.80)], x_[-int(len(x_)*.20):]
    y_train, y_test = y_[:int(len(y_)*.80)], y_[-int(len(y_)*.20):]
    
    print("X train shape: ", x_train.shape)
    print("X test shape: ", x_test.shape)
    print("Y train shape: ", y_train.shape)
    print("Y test shape: ", y_test.shape)
    
    return x_train, x_test, y_train, y_test

# %%
def build_CNN(convLayer, denseLayer, nodes):
    model = keras.Sequential()

    model.add(keras.layers.Conv1D(nodes, 3, input_shape=(x_train.shape[1:]), data_format="channels_first", activation="relu"))
    model.add(keras.layers.MaxPooling1D(pool_size=2, padding='same'))

    for l in range(convLayer-1):
        model.add(keras.layers.Conv1D(nodes, 3, activation="relu"))
        model.add(keras.layers.MaxPooling1D(pool_size=2, padding='same'))

    model.add(keras.layers.Dropout(.5))
    model.add(keras.layers.Flatten())

    for l in range(denseLayer-1):
        model.add(keras.layers.Dense(nodes, activation="relu"))

    model.add(keras.layers.Dense(10, activation="softmax"))
    return model

# %%
def get_tensorboard(model_name, logdir):
    tensorboard = TensorBoard(log_dir=f'{logdir}\\{model_name}')
    #tensorboard = TensorBoard(log_dir=f'logs\\{model_name}')
    print("Model Name:", model_name)
    return tensorboard

# %% [markdown]
# ## Hyper-Parameter Search

# %%
conv_layers = [3,2]
dense_layers = [2,1]
layer_sizes = [256,64,16]

# %%
# Data Files and Data Sets
data_files = ["EP_preprocessed_x.h5"]

data_sets = ["EP_preprocessed_x_dataset"]

# %%
for i in range(len(data_files)):
    x_train, x_test, y_train, y_test = train_test_split(data_files[i], data_sets[i])
    
    for conv_layer in conv_layers:
        for dense_layer in dense_layers:
            for layer_size in layer_sizes:

                # --- Tensorboard Callback ---
                NAME = f"CNN-{conv_layer}-conv-{dense_layer}-dense-{layer_size}-nodes-{int(time.time())}"
                tensorboard = get_tensorboard(model_name=NAME, logdir='logs_ConvNet')

                # --- Convolutional Neural Network ---
                model = build_CNN(conv_layer, dense_layer, layer_size)
                model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])    
                model.fit(x_train, y_train, epochs=10, validation_data=(x_test,y_test), callbacks=[tensorboard])
# Out:
# X train shape:  (51876, 14, 250)
# X test shape:  (12969, 14, 250)
# Y train shape:  (51876, 10)
# Y test shape:  (12969, 10)
# Model Name: CNN-3-conv-2-dense-256-nodes-1581191179
# Train on 51876 samples, validate on 12969 samples
# Epoch 1/10
# Epoch 3/10
# 51876/51876 [==============================] - 11s 203us/sample - loss: 2.3026 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.0995
# Epoch 4/10
# 51876/51876 [==============================] - 10s 199us/sample - loss: 2.3027 - accuracy: 0.0994 - val_loss: 2.3026 - val_accuracy: 0.1023
# Epoch 5/10
# 51876/51876 [==============================] - 11s 205us/sample - loss: 2.3026 - accuracy: 0.1024 - val_loss: 2.3028 - val_accuracy: 0.0987
# Epoch 6/10
# 51876/51876 [==============================] - 11s 204us/sample - loss: 2.3026 - accuracy: 0.0996 - val_loss: 2.3027 - val_accuracy: 0.0999
# Epoch 7/10
# 51876/51876 [==============================] - 11s 206us/sample - loss: 2.3027 - accuracy: 0.0996 - val_loss: 2.3026 - val_accuracy: 0.1020
# Epoch 8/10
# 51876/51876 [==============================] - 11s 202us/sample - loss: 2.3025 - accuracy: 0.1010 - val_loss: 2.3027 - val_accuracy: 0.1023
# Epoch 9/10
# 51876/51876 [==============================] - 11s 205us/sample - loss: 2.3025 - accuracy: 0.0998 - val_loss: 2.3026 - val_accuracy: 0.1028
# Epoch 10/10
# 51876/51876 [==============================] - 10s 202us/sample - loss: 2.3025 - accuracy: 0.0983 - val_loss: 2.3028 - val_accuracy: 0.1031
# Model Name: CNN-2-conv-2-dense-256-nodes-1581192205
# Train on 51876 samples, validate on 12969 samples
# Epoch 1/10
# 51876/51876 [==============================] - 27s 519us/sample - loss: 2.3035 - accuracy: 0.0994 - val_loss: 2.3031 - val_accuracy: 0.0979
# Epoch 2/10
# 51876/51876 [==============================] - 26s 499us/sample - loss: 2.3031 - accuracy: 0.1016 - val_loss: 2.3027 - val_accuracy: 0.1002
# Epoch 3/10
# 51876/51876 [==============================] - 26s 500us/sample - loss: 2.3031 - accuracy: 0.0989 - val_loss: 2.3027 - val_accuracy: 0.0998
# Epoch 4/10
# 51876/51876 [==============================] - 26s 500us/sample - loss: 2.3029 - accuracy: 0.0978 - val_loss: 2.3031 - val_accuracy: 0.0994
# Epoch 5/10
# 51876/51876 [==============================] - 26s 500us/sample - loss: 2.3025 - accuracy: 0.1008 - val_loss: 2.3028 - val_accuracy: 0.1026
# Epoch 6/10
# 51876/51876 [==============================] - 26s 500us/sample - loss: 2.3019 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.1006
# Epoch 7/10
# 51876/51876 [==============================] - 26s 499us/sample - loss: 2.3013 - accuracy: 0.1018 - val_loss: 2.3038 - val_accuracy: 0.0978
# Epoch 8/10
# 51876/51876 [==============================] - 26s 501us/sample - loss: 2.3003 - accuracy: 0.1022 - val_loss: 2.3042 - val_accuracy: 0.1001
# Epoch 9/10
# 51876/51876 [==============================] - 26s 503us/sample - loss: 2.2993 - accuracy: 0.1056 - val_loss: 2.3051 - val_accuracy: 0.1002
# Epoch 10/10
# 51876/51876 [==============================] - 26s 502us/sample - loss: 2.2983 - accuracy: 0.1044 - val_loss: 2.3049 - val_accuracy: 0.1019
# Model Name: CNN-2-conv-2-dense-64-nodes-1581192467
# Train on 51876 samples, validate on 12969 samples
# Epoch 1/10
#    32/51876 [..............................] - ETA: 19:46 - loss: 2.3101 - accuracy: 0.0312WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.105259). Check your callbacks.
# 51876/51876 [==============================] - 12s 239us/sample - loss: 2.3031 - accuracy: 0.0995 - val_loss: 2.3026 - val_accuracy: 0.1014
# Epoch 2/10
# 51876/51876 [==============================] - 11s 217us/sample - loss: 2.3029 - accuracy: 0.0987 - val_loss: 2.3028 - val_accuracy: 0.0989
# Epoch 3/10
# 51876/51876 [==============================] - 11s 218us/sample - loss: 2.3028 - accuracy: 0.1003 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 4/10
# 51876/51876 [==============================] - 11s 217us/sample - loss: 2.3028 - accuracy: 0.1009 - val_loss: 2.3027 - val_accuracy: 0.1032
# Epoch 5/10
# 51876/51876 [==============================] - 11s 218us/sample - loss: 2.3025 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.1002
# Epoch 6/10
# 51876/51876 [==============================] - 11s 216us/sample - loss: 2.3023 - accuracy: 0.1009 - val_loss: 2.3036 - val_accuracy: 0.1032
# Epoch 7/10
# 51876/51876 [==============================] - 11s 217us/sample - loss: 2.3024 - accuracy: 0.1003 - val_loss: 2.3034 - val_accuracy: 0.1041
# Epoch 8/10
# 51876/51876 [==============================] - 11s 213us/sample - loss: 2.3019 - accuracy: 0.1027 - val_loss: 2.3036 - val_accuracy: 0.0982
# Epoch 9/10
# 51876/51876 [==============================] - 11s 217us/sample - loss: 2.3018 - accuracy: 0.1024 - val_loss: 2.3031 - val_accuracy: 0.1028
# Epoch 10/10
# 51876/51876 [==============================] - 11s 216us/sample - loss: 2.3014 - accuracy: 0.1030 - val_loss: 2.3037 - val_accuracy: 0.1027
# Model Name: CNN-2-conv-2-dense-16-nodes-1581192581
# Train on 51876 samples, validate on 12969 samples
# Epoch 1/10
# 51876/51876 [==============================] - 11s 212us/sample - loss: 2.3029 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0999
# Epoch 2/10
# 51876/51876 [==============================] - 10s 195us/sample - loss: 2.3027 - accuracy: 0.0999 - val_loss: 2.3027 - val_accuracy: 0.0999
# Epoch 3/10
# 51876/51876 [==============================] - 10s 195us/sample - loss: 2.3027 - accuracy: 0.1010 - val_loss: 2.3026 - val_accuracy: 0.1024
# Epoch 4/10
# 51876/51876 [==============================] - 10s 198us/sample - loss: 2.3026 - accuracy: 0.1024 - val_loss: 2.3028 - val_accuracy: 0.1019
# Epoch 5/10
# 51876/51876 [==============================] - 10s 198us/sample - loss: 2.3027 - accuracy: 0.1012 - val_loss: 2.3027 - val_accuracy: 0.1025
# Epoch 6/10
# 51876/51876 [==============================] - 10s 197us/sample - loss: 2.3026 - accuracy: 0.0984 - val_loss: 2.3031 - val_accuracy: 0.1013
# Epoch 7/10
# 51876/51876 [==============================] - 10s 197us/sample - loss: 2.3026 - accuracy: 0.0995 - val_loss: 2.3031 - val_accuracy: 0.1027
# Epoch 8/10
# 51876/51876 [==============================] - 10s 192us/sample - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3027 - val_accuracy: 0.1017
# Epoch 9/10
# 51876/51876 [==============================] - 10s 198us/sample - loss: 2.3024 - accuracy: 0.1026 - val_loss: 2.3030 - val_accuracy: 0.1032
# Epoch 10/10
# 51876/51876 [==============================] - 10s 197us/sample - loss: 2.3022 - accuracy: 0.1012 - val_loss: 2.3030 - val_accuracy: 0.1002
# Model Name: CNN-2-conv-1-dense-256-nodes-1581192684
# Train on 51876 samples, validate on 12969 samples
# Epoch 1/10
# 51876/51876 [==============================] - 23s 449us/sample - loss: 2.3036 - accuracy: 0.1018 - val_loss: 2.3033 - val_accuracy: 0.0999
# Epoch 2/10
# 51876/51876 [==============================] - 22s 428us/sample - loss: 2.3035 - accuracy: 0.1009 - val_loss: 2.3030 - val_accuracy: 0.1003
# Epoch 3/10
# 51876/51876 [==============================] - 22s 431us/sample - loss: 2.3031 - accuracy: 0.1024 - val_loss: 2.3032 - val_accuracy: 0.1024
# Epoch 4/10
# 51876/51876 [==============================] - 22s 429us/sample - loss: 2.3024 - accuracy: 0.1040 - val_loss: 2.3044 - val_accuracy: 0.1012
# Epoch 5/10
# 51876/51876 [==============================] - 22s 428us/sample - loss: 2.3024 - accuracy: 0.1023 - val_loss: 2.3031 - val_accuracy: 0.0983
# Epoch 6/10
# 51876/51876 [==============================] - 22s 429us/sample - loss: 2.3016 - accuracy: 0.1034 - val_loss: 2.3038 - val_accuracy: 0.1025
# Epoch 7/10
# 51876/51876 [==============================] - 22s 430us/sample - loss: 2.2999 - accuracy: 0.1037 - val_loss: 2.3040 - val_accuracy: 0.1029
# Epoch 8/10
# 51876/51876 [==============================] - 22s 428us/sample - loss: 2.2991 - accuracy: 0.1058 - val_loss: 2.3065 - val_accuracy: 0.1029
# Epoch 9/10
# 51876/51876 [==============================] - 22s 430us/sample - loss: 2.2982 - accuracy: 0.1053 - val_loss: 2.3052 - val_accuracy: 0.0992
# Epoch 10/10
# 51876/51876 [==============================] - 22s 429us/sample - loss: 2.2968 - accuracy: 0.1050 - val_loss: 2.3058 - val_accuracy: 0.1018
# Model Name: CNN-2-conv-1-dense-64-nodes-1581192909
# Train on 51876 samples, validate on 12969 samples
# Epoch 1/10
# 51876/51876 [==============================] - 12s 226us/sample - loss: 2.3030 - accuracy: 0.1025 - val_loss: 2.3027 - val_accuracy: 0.0999
# Epoch 2/10
# 51876/51876 [==============================] - 11s 209us/sample - loss: 2.3029 - accuracy: 0.0991 - val_loss: 2.3028 - val_accuracy: 0.1004
# Epoch 3/10
# 51876/51876 [==============================] - 11s 210us/sample - loss: 2.3028 - accuracy: 0.1003 - val_loss: 2.3026 - val_accuracy: 0.1021
# Epoch 4/10
# 51876/51876 [==============================] - 11s 210us/sample - loss: 2.3025 - accuracy: 0.1017 - val_loss: 2.3028 - val_accuracy: 0.1030
# Epoch 5/10
# 51876/51876 [==============================] - 11s 209us/sample - loss: 2.3024 - accuracy: 0.1000 - val_loss: 2.3031 - val_accuracy: 0.0975
# Epoch 6/10
# 51876/51876 [==============================] - 11s 209us/sample - loss: 2.3017 - accuracy: 0.1010 - val_loss: 2.3033 - val_accuracy: 0.1032
# Epoch 7/10
# 51876/51876 [==============================] - 11s 210us/sample - loss: 2.3015 - accuracy: 0.1019 - val_loss: 2.3033 - val_accuracy: 0.1036
# Epoch 8/10
# 51876/51876 [==============================] - 11s 209us/sample - loss: 2.3016 - accuracy: 0.1032 - val_loss: 2.3029 - val_accuracy: 0.0990
# Epoch 9/10
# 51876/51876 [==============================] - 11s 211us/sample - loss: 2.3008 - accuracy: 0.1025 - val_loss: 2.3036 - val_accuracy: 0.1029
# Epoch 10/10
# 51876/51876 [==============================] - 11s 209us/sample - loss: 2.3003 - accuracy: 0.1039 - val_loss: 2.3041 - val_accuracy: 0.0978
# Model Name: CNN-2-conv-1-dense-16-nodes-1581193020
# Train on 51876 samples, validate on 12969 samples
# Epoch 1/10
# 51876/51876 [==============================] - 11s 210us/sample - loss: 2.3028 - accuracy: 0.1015 - val_loss: 2.3026 - val_accuracy: 0.0990
# Epoch 2/10
# 51876/51876 [==============================] - 10s 192us/sample - loss: 2.3027 - accuracy: 0.0967 - val_loss: 2.3026 - val_accuracy: 0.1024
# Epoch 3/10
# 51876/51876 [==============================] - 10s 191us/sample - loss: 2.3026 - accuracy: 0.1005 - val_loss: 2.3027 - val_accuracy: 0.1024
# Epoch 4/10
# 51876/51876 [==============================] - 10s 186us/sample - loss: 2.3026 - accuracy: 0.1006 - val_loss: 2.3024 - val_accuracy: 0.1061
# Epoch 5/10
# 51876/51876 [==============================] - 10s 191us/sample - loss: 2.3027 - accuracy: 0.1011 - val_loss: 2.3023 - val_accuracy: 0.1036
# Epoch 6/10
# 51876/51876 [==============================] - 10s 191us/sample - loss: 2.3022 - accuracy: 0.1014 - val_loss: 2.3023 - val_accuracy: 0.1024
# Epoch 7/10
# 51876/51876 [==============================] - 10s 191us/sample - loss: 2.3019 - accuracy: 0.1038 - val_loss: 2.3015 - val_accuracy: 0.1098
# Epoch 8/10
# 51876/51876 [==============================] - 10s 183us/sample - loss: 2.3014 - accuracy: 0.1053 - val_loss: 2.3007 - val_accuracy: 0.1092
# Epoch 9/10
# 51876/51876 [==============================] - 10s 191us/sample - loss: 2.2998 - accuracy: 0.1111 - val_loss: 2.2981 - val_accuracy: 0.1255
# Epoch 10/10
# 51876/51876 [==============================] - 10s 189us/sample - loss: 2.2977 - accuracy: 0.1154 - val_loss: 2.2959 - val_accuracy: 0.1258
