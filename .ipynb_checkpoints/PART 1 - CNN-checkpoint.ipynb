# %%
import numpy as np
import h5py
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import TensorBoard

# %% [markdown]
# ## Functions

# %%
def load_data(filename, dataname):
    with h5py.File(filename, 'r') as hf:
        x = hf[dataname][:]
    with h5py.File('EP_preprocessed_y.h5', 'r') as hf:
        y = hf['EP_preprocessed_y_dataset'][:]
    return x,y

# %%
def reshape_x(pre_x, channels, timepoints):
    new_x = np.reshape(pre_x, (pre_x.shape[0], channels, timepoints))
    return new_x

# %%
def train_test_split(file, data):
    x_,y_ = load_data(file, data)
    
    x_train, x_test = x_[:int(len(x_)*.80)], x_[-int(len(x_)*.20):]
    y_train, y_test = y_[:int(len(y_)*.80)], y_[-int(len(y_)*.20):]
    
    print("X train shape: ", x_train.shape)
    print("X test shape: ", x_test.shape)
    print("Y train shape: ", y_train.shape)
    print("Y test shape: ", y_test.shape)
    
    return x_train, x_test, y_train, y_test

# %%
def build_CNN(convLayer, denseLayer, nodes):
    model = keras.Sequential()

    model.add(keras.layers.Conv1D(nodes, 3, input_shape=(x_train.shape[1:]), data_format="channels_first", activation="relu"))
    model.add(keras.layers.MaxPooling1D(pool_size=2))

    for l in range(convLayer-1):
        model.add(keras.layers.Conv1D(nodes, 3, activation="relu"))
        model.add(keras.layers.MaxPooling1D(pool_size=2))

    model.add(keras.layers.Dropout(.5))
    model.add(keras.layers.Flatten())

    for l in range(denseLayer-1):
        model.add(keras.layers.Dense(nodes, activation="relu"))

    model.add(keras.layers.Dense(10, activation="softmax"))
    return model

# %%
def get_tensorboard(model_name, logdir):
    tensorboard = TensorBoard(log_dir=f'{logdir}\\{model_name}')
    #tensorboard = TensorBoard(log_dir=f'logs\\{model_name}')
    print("Model Name:", model_name)
    return tensorboard

# %% [markdown]
# ## Hyper-Parameter Search

# %%
conv_layers = [2,3]
dense_layers = [1,2]
layer_sizes = [16,64,256]

# %%
# Data Files and Data Sets
data_files = ["EP_preprocessed_x.h5"]

data_sets = ["EP_preprocessed_x_dataset"]

# %%
for i in range(len(data_files)):
    x_train, x_test, y_train, y_test = train_test_split(data_files[i], data_sets[i])
    
    for conv_layer in conv_layers:
        for dense_layer in dense_layers:
            for layer_size in layer_sizes:

                # --- Tensorboard Callback ---
                NAME = f"CNN-{conv_layer}-conv-{layer_size}-nodes-{dense_layer}-dense-{int(time.time())}"
                tensorboard = get_tensorboard(model_name=NAME, logdir='logs_CNN')

                # --- Convolutional Neural Network ---
                model = build_CNN(conv_layer, dense_layer, layer_size)
                model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])    
                model.fit(x_train, y_train, epochs=50, validation_data=(x_test,y_test), callbacks=[tensorboard])
# Out:
# X train shape:  (51876, 14, 250)
# X test shape:  (12969, 14, 250)
# Y train shape:  (51876, 10)
# Y test shape:  (12969, 10)
# Model Name: CNN-2-conv-16-nodes-1-dense-1581178113
# Train on 51876 samples, validate on 12969 samples
# Epoch 1/50
# Epoch 9/50
# 51876/51876 [==============================] - 22s 425us/sample - loss: 2.2985 - accuracy: 0.1072 - val_loss: 2.3065 - val_accuracy: 0.0972
# Epoch 10/50
# 51876/51876 [==============================] - 22s 427us/sample - loss: 2.2977 - accuracy: 0.1079 - val_loss: 2.3067 - val_accuracy: 0.1027
# Epoch 11/50
# 51876/51876 [==============================] - 22s 427us/sample - loss: 2.2958 - accuracy: 0.1040 - val_loss: 2.3055 - val_accuracy: 0.1051
# Epoch 12/50
# 51876/51876 [==============================] - 23s 437us/sample - loss: 2.2930 - accuracy: 0.1106 - val_loss: 2.3075 - val_accuracy: 0.1033
# Epoch 13/50
# 51876/51876 [==============================] - 22s 432us/sample - loss: 2.2916 - accuracy: 0.1113 - val_loss: 2.3071 - val_accuracy: 0.1012
# Epoch 14/50
# 51876/51876 [==============================] - 22s 430us/sample - loss: 2.2892 - accuracy: 0.1140 - val_loss: 2.3098 - val_accuracy: 0.1017
# Epoch 15/50
# 51876/51876 [==============================] - 23s 438us/sample - loss: 2.2877 - accuracy: 0.1155 - val_loss: 2.3125 - val_accuracy: 0.1032
# Epoch 16/50
# 51876/51876 [==============================] - 22s 431us/sample - loss: 2.2851 - accuracy: 0.1166 - val_loss: 2.3107 - val_accuracy: 0.1032
# Epoch 17/50
# 51876/51876 [==============================] - 22s 429us/sample - loss: 2.2820 - accuracy: 0.1169 - val_loss: 2.3138 - val_accuracy: 0.1035
# Epoch 18/50
# 51876/51876 [==============================] - 22s 426us/sample - loss: 2.2799 - accuracy: 0.1170 - val_loss: 2.3143 - val_accuracy: 0.1087
# Epoch 19/50
# 51876/51876 [==============================] - 22s 426us/sample - loss: 2.2769 - accuracy: 0.1188 - val_loss: 2.3191 - val_accuracy: 0.1040
# Epoch 20/50
# 51876/51876 [==============================] - 22s 427us/sample - loss: 2.2749 - accuracy: 0.1236 - val_loss: 2.3176 - val_accuracy: 0.1047
# Epoch 21/50
# 51876/51876 [==============================] - 22s 431us/sample - loss: 2.2708 - accuracy: 0.1273 - val_loss: 2.3217 - val_accuracy: 0.1010
# Epoch 22/50
# 51876/51876 [==============================] - 22s 433us/sample - loss: 2.2671 - accuracy: 0.1281 - val_loss: 2.3265 - val_accuracy: 0.1041
# Epoch 23/50
# 51876/51876 [==============================] - 22s 426us/sample - loss: 2.2626 - accuracy: 0.1302 - val_loss: 2.3270 - val_accuracy: 0.1081
# Epoch 24/50
# 51876/51876 [==============================] - 22s 424us/sample - loss: 2.2614 - accuracy: 0.1315 - val_loss: 2.3278 - val_accuracy: 0.1030
# Epoch 25/50
# 51876/51876 [==============================] - 22s 424us/sample - loss: 2.2562 - accuracy: 0.1355 - val_loss: 2.3345 - val_accuracy: 0.1091
# Epoch 26/50
#  2080/51876 [>.............................] - ETA: 18s - loss: 2.2426 - accuracy: 0.1394
